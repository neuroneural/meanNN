# %%
# %matplotlib notebook
import torch
import numpy as np
import cv2
import ipdb
import scipy
import os

from torch import nn
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

from numpy import dot
from numpy.linalg import matrix_rank, inv
from numpy.random import permutation
from scipy.linalg import eigh
from scipy.linalg import norm as mnorm
from scipy.stats import entropy

import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, RandomSampler
from torch.optim.lr_scheduler import CosineAnnealingLR, OneCycleLR

# %%
def entropyLoss(X, use_gpu=True):
    if use_gpu:
        entropy = torch.tensor([0]).type(torch.float32).cuda()
    else:
        entropy = torch.tensor([0]).type(torch.float32)
        
    for batch in X:
        d = batch.shape[0]
        n = batch.shape[1]
        
        if use_gpu:
            eigen = torch.eye(n, n).cuda()
        else:
            eigen = torch.eye(n, n)
        squared_norms = (batch**2).sum(0).repeat(n, 1)
        squared_norms_T = squared_norms.T
        batch_T = batch.T
        arg = squared_norms + squared_norms_T - 2 * torch.mm(batch_T, batch)
        expression = torch.sum(torch.log(torch.abs(arg)+ eigen + 1e-12))/2
        entropy += -d/(n*(n-1)) * expression
    return entropy/X.size()[0]

# %%
a = np.random.rand(1024, 2)

# %%
entropyLoss(torch.from_numpy(a).float().T.unsqueeze(0), use_gpu=False)
# Out:
# tensor([1.6056])

# %%
heart = Image.open('./heart.png')
fox = Image.open('./fox.png')
flower = Image.open('./flower.png')
num_of_img = 2

heart = np.array(ImageOps.grayscale(heart))
fox = np.array(ImageOps.grayscale(fox))
flower = np.array(ImageOps.grayscale(flower))

resize = 128

heart = cv2.resize(heart,(resize,resize))
fox = cv2.resize(fox,(resize,resize))
flower = cv2.resize(flower, (resize,resize))

# %%
l = []
m = []

for i in range(100):
    l.append(np.random.rand(1))
    
for i in range(100):
    m.append(np.random.rand(1))

# %%
fig = plt.figure()
ax = fig.add_subplot(121)
ax1 = fig.add_subplot(122)
# plt.ion()

# fig.show()
# fig.canvas.draw()

for i in range(0,100):
    ax.clear()
    ax.plot(l[0:i])
    fig.canvas.draw()
    
    ax1.clear()
    ax1.plot(m[0:i])
    fig.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /data/users2/yxiao11/anaconda3/envs/p37/lib/python3.7/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     503     try:
# --> 504         fh = fp.fileno()
#     505         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_1555142/2303664218.py in <module>
#      10     ax.clear()
#      11     ax.plot(l[0:i])
# ---> 12     fig.canvas.draw()
#      13
#      14     ax1.clear()
#
# /data/users2/yxiao11/anaconda3/envs/p37/lib/python3.7/site-packages/matplotlib/backends/backend_webagg_core.py in draw(self)
#     153             super().draw()
#     154         finally:
# ...
